# %% [markdown]
# # IMPLEMENTATION DETAILS
# ### TYPE - ANN Regression
# ### PROJECT - "Black Friday Sales"

# %% [markdown]
# # A. DATA ASSESSMENT PROCESS

# %% [markdown]
# ## 1. DATASET SUMMARY
# ### - It is 'Black Friday Sales' dataset that provides the information about various features to predict the sales of products at a retail store.
# ### - There are 5,50,068 observations and 12 features in the dataset.
# ### - Total 'float' type features are 2, 'integer' type features are 5, and 'object' type features are 5.
# #### - float type : ['Product_Category_2', 'Product_Category_3']
# #### - int type : ['User_ID', 'Occupation', 'Marital_Status', 'Product_Category_1', 'Purchase']
# #### - object type : ['Product_ID', 'Gender', 'Age', 'City_Category', 'Stay_In_Current_City_Years']
# ### - For ML and AI applications 'Purchase' feature is the target variable (dependent) and the other 11 features are input (independent).

# %% [markdown]
# ## 2. FEATURE DESCRIPTIONS
# ### Table - 'bfs' using 'bfs_train.csv'
# ### * Independent Features
# #### - **'User_ID'** {integer} : ***Unique ID of the customer.***
# #### - **'Product_ID'** {object} : ***Unique ID of the product purchased.***
# #### - **'Gender'** {object} : ***Gender of the customer.***
# #### - **'Age'** {object} : ***Age of the customer in the specified ranges or bins.***
# #### - **'Occupation'** {integer} : ***Work profile of the customer. (masked)***
# #### - **'City_Category'** {object} : ***Category of the city where purchase is made.***
# #### - **'Stay_In_Current_City_Years'** {object} : ***Number of years customer staying in the city.***
# #### - **'Marital_Status'** {integer} : ***Married (1) or not (0).***
# #### - **'Product_Category_1'** {integer} : ***Main category of the product. (masked)***
# #### - **'Product_Category_2'** {float} : ***First sub-category of the product. Product may belong to other category. (masked)***
# #### - **'Product_Category_3'** {float} : ***Second sub-category of the product. Product may belong to other category .(masked)***
#
# ### * Dependent Feature
# #### - **'Purchase'** {integer} : ***Purchase amount in dollars.***
# ##### This feature is the target variable for Machine Learning Based Regression Type Problems.

# %% [markdown]
# ## 3. DATA ISSUES
# ### Table - cc
# #### 1. * Dirty Data (Low quality)
# ##### A. Completeness
# ##### - Missing values in 'Product_Category_2' are 173638 {31.56 %}.
# ##### - Missing values in 'Product_Category_3' are 383247 {69.67 %}.
# ##### B. Validity
# ##### - Data type of certain features can be fixed or changed.
# ##### - No data duplication in the dataset.
# ##### C. Accuracy
# ##### - No inaccuracy issue
# ##### D. Consistency
# ##### - No inconsistency issue
#
# #### 2. * Messy Data (Untidy / Structural)
# ##### - No messy data issue

# %% [markdown]
# # B. PRE-PROCESSING / DATA CLEANING

# %% [markdown]
# ## 1. Pre-Processing Level - I.
#
# ### - Nothing to pre-process
#
# ### - Splitting the dataframe into Train, Validation, and Test datasets using 'bms_train.csv', ***successful***.
#
# ### - Saving the split data into CSV and PKL files, ***successful***.
# #### . Train ('bfs_train_init.csv','bfs_train_init.pkl')
# #### . Validation ('bfs_valid_init.csv','bfs_valid_init.pkl')
# #### . Test ('bfs_test_init.csv','bfs_test_init.pkl')

# %% [markdown]
# ## 2. Pre-Processing Level - II. (Train, Validation, and Test datasets)
#
# ### - Missing value handling and imputation, ***successful***.
# ### - Changing the datatype of certain features, ***successful***.
#
# ### - Saving the pre-processed data into CSV and PKL files, ***successful***.
# #### . Train ('bfs_train_pp.csv','bfs_train_pp.pkl')
# #### . Validation ('bfs_valid_pp.csv','bfs_valid_pp.pkl')
# #### . Test ('bfs_test_pp.csv','bfs_test_pp.pkl')

# %% [markdown]
# # C. EDA CONCLUSIONS

# %% [markdown]
# ## 1. Uni-Variate EDA conclusions
#
# ### Numerical Features
# #### - Total numerical features: 1 ['Purchase']
# #### - This feature is the target feature for ML applications.
# #### - There are no missing values in the feature.
#
# #### - SKEWNESS:
# ##### - Moderate: positive(Purchase), negative()
#
# #### - Total outliers are 2674 (0.4863) % for the feature.
#
#
# ### Categorical Features
# #### - Total categorical features: 11 ['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category', 'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1', 'Product_Category_2', 'Product_Category_3']
#
# #### - 'User_ID' and 'Product_ID' are the features which are identifiers for the users and products. So, will be dropped during model buidling process.
#
# #### - Features with lot of labels or categories (>=15) are ['Occupation', 'Product_Category_1', 'Product_Category_2', 'Product_Category_3'], other features have 2-6 categories.

# %% [markdown]
# ## 2. Bi/Multi Variate EDA conclusions
#
# ### Categorical-Numerical, 'Purchase' vs others
#
# #### - Outliers exist for 'Purchase' across labels of various categorical features for lower, upper, or both sides.
#
# #### - Distribution of 'Purchase' for labels of various features is nearly same, except few feature labels.
#
# #### - Males are purchasing more than females. Females are generally making more smaller purchases upto 11k and males beyond 11k.
#
# #### - Older users above (50 years) are purchasing more than younger users.
#
# #### - Occupations with higher purchase values are 12,15,17 and lower values are 9,19,20.
#
# #### - City category 'C' has higher purchase and 'A' has lower values.
#
# #### - Average 'Purchase' value is nearly same for all the labels of Stay_In_Current_City_Years.
#
# #### - Singles and married are nearly same for purchase values.
#
# #### - Average value of 'Purchase' is highest for Product_Category_1 label 17 and lowest for label 19.
#
# #### - Average value of 'Purchase' is highest for Product_Category_2 label 10 and lowest for label 7.
#
# #### - Average value of 'Purchase' is highest for Product_Category_3 label 3 and lowest for label 14.
#
#
# ### Categorical-Categorical
#
# #### - Males have contributed more towards purchases than females across all ages, occupations, city categories, stay in current city years, marital status, and different product categories 1,2,3 with few exceptions.
#
# #### - Older users are generally making more purchases across all occupations, city categories, stay in current city years, marital status, and various product categories 1,2,3 with few exceptions for labels.
#
# #### - Occupations contributing more or less purchases are varying across labels of city categories, stay in current city years, marital status, and various product categories 1,2,3.
#
# #### - City category 'C' is giving more purchases across labels of stay in current city years, marital status, and various product categories 1,2,3 with few exceptions.
#
# #### - Married users staying in city for longer duration are giving more purchases than singles. Users with longer stay in city are generally giving more purchases, but there are variations across labels of product categories 1,2,3.
#
# #### - Purchases for singles and married are varying across labels of product_categories 1,2,3. Generally married are contributing more for purchases.

# %% [markdown]
# # D. FEATURE ENGINEERING

# %% [markdown]
# ## A. Observations
#
# ### 1. Target variable transformation to reduce skew or scale.
# ### 2. Drop non relevant features from the dataset. (Pipeline)
# ### 3. Categorical data encoding using Ordinal Encoding Techniques. (Pipeline)
# ### 4. Categorical data encoding using One Hot Encoding. (Pipeline)
# ### 5. Feature selection to increase the performance of the model. (Pipeline) **(NOT DONE)**

# %% [markdown]
# ## B. Steps of Feature Engineering
#
# ### 1. Target Feature Transformation.
# #### Checking various features transformations: ***Log Transformer, Quantile Transformer, and Power Transformer***.
# #### Applying Power Transformer to target feature as giving better results than other two.
#
# ### 2. Drop non relevant features from the observations ['User_ID','Product_ID'], unique in the dataset (to be applied in the pipeline).
#
# ### 3. Categorical features handling using Ordinal encoding techniques (to be applied in the pipeline).
# #### Features: ['Age','City_Category','Stay_In_Current_City_Years']
#
# ### 4. Categorical features handling using OneHot encoding techniques (to be applied in the pipeline).
# #### Features: ['Gender','Occupation','Marital_Status','Product_Category_1','Product_Category_2','Product_Category_3']
#
# ### 5. Feature Selection Techniques (to be applied in pipeline) **(NOT DONE)**.
# #### - Apply SelectKBest with mutual_info_regression to select the top k features for Model Building using estimators.
# #### - Treat Train, Validation, and Test dataset with feature selection strategy.

# %% [markdown]
# ## C. Saving the feature engineered train and test datasets into CSV and PKL files
# ### - Train dataset.
# #### - 'bfs_train_fe.csv'
# #### - 'bfs_train_fe.pkl'
#
# ### - Validation and Test data.
# #### - 'bfs_valid_fe.csv'
# #### - 'bfs_valid_fe.pkl'
# #### - 'bfs_test_fe.csv'
# #### - 'bfs_test_fe.pkl'

# %% [markdown]
# # E. ML MODELS IMPLEMENTATIONS & RESULTS

# %% [markdown]
# ## A. Simple Model-1
#
# #### 1. Feature Engineering. (One Hot Encoding, Ordinal Encoding)
# #### 2. No Hyper Parameters tuning used.
#
# #### 3. Input Dataset Size:
# - X-Train Dataset size : (549868, 74)
# - X-Validation Dataset size : (100, 74)
#
#
# #### 4. Model: ANN Model
#     def build_model():
#         model = Sequential()
#         model.add(Dense(74, activation='relu', input_dim=74))
#
#         model.add(Dense(1, activation='linear'))
#
#         model.compile(optimizer='Adam', loss='mean_squared_error')
#
#         return model
#
#     best_mdl = build_model()
#     best_mdl.summary()
#     hst = best_mdl.fit(Xtr, ytr, epochs=4, verbose=1, validation_data=(Xval,yval))
#
# #### 5. Results:
# - R2 Score :
#   - Train Dataset: 64.2808 %
#   - Validation Dataset: 67.2622 %
#
# - RMSE Score :
#   - Train Dataset: 3002.0481
#   - Validation Dataset: 2740.1087
#
# #### 6. Conclusions:
# - ***Acceptable performance for Train and Validation sets.***
# - ***Model is performing better on validation dataset in comparison to train dataset.***

# %% [markdown]
# ## B. Simple Model-2
#
# #### 1. Feature Engineering. (One Hot Encoding, Ordinal Encoding)
# #### 2. No Hyper Parameters tuning used.
#
# #### 3. Input Dataset Size:
# - X-Train Dataset size : (549868, 74)
# - X-Validation Dataset size : (100, 74)
#
#
# #### 4. Model: ANN Model
#
#     def build_model():
#         model = Sequential()
#
#         model.add(Dense(74, activation='relu', input_dim=74))
#         model.add(Dense(148, activation='relu'))
#         model.add(Dense(1, activation='linear'))
#
#         model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')
#
#         return model
#
#     best_mdl = build_model()
#     best_mdl.summary()
#     hst = best_mdl.fit(Xtr, ytr, epochs=10, verbose=1, validation_data=(Xval,yval))
#
# #### 5. Results:
# - R2 Score :
#   - Train Dataset: 65.0989 %
#   - Validation Dataset: 66.5071 %
#
# - RMSE Score :
#   - Train Dataset: 2967.4732
#   - Validation Dataset: 2771.5287
#
# #### 6. Conclusions:
# - ***Acceptable performance for Train and Validation sets.***
# - ***Model is performing better on validation dataset in comparison to train dataset.***

# %% [markdown]
# ## C. All ANN Model Hyper-Tuned using Feature Engineered Data

# %% [raw]
# # model:1
# def model_m1():
#     model = Sequential()
#
#     model.add(Dense(74, activation='relu', input_dim=74))
#     model.add(Dense(1, activation='linear'))
#
#     model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), loss='mean_squared_error')
#
#     return model
#
# RESULT:
# -----------------------------
#
# M1: epochs(19)
# R2 Score :
# Train Dataset: 65.6329 %
# Validation Dataset: 67.8004 %
#
#
# RMSE Score :
# Train Dataset: 2944.6805
# Validation Dataset: 2717.4939
#
# -------------------------------------------------------------------------------------------------------------------------------
#
# # model:2
# def model_m2():
#     model = Sequential()
#
#     model.add(Dense(35, activation='relu', input_dim=74))
#     model.add(Dropout(0.5))
#     model.add(Dense(1, activation='linear'))
#
#     model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')
#
#     return model
#
# RESULT:
# -----------------------------
#
# M2: epochs(12)
# R2 Score :
# Train Dataset: 63.8386 %
# Validation Dataset: 67.4648 %
#
#
# RMSE Score :
# Train Dataset: 3020.5746
# Validation Dataset: 2731.6173
#
# -------------------------------------------------------------------------------------------------------------------------------
#
# # model:3
# def model_m3():
#     model = Sequential()
#
#     model.add(Dense(40, activation='tanh', input_dim=74))
#     model.add(Dropout(0.3))
#     model.add(Dense(1, activation='linear'))
#
#     model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001), loss='mean_squared_error')
#
#     return model
#
# RESULT:
# -----------------------------
#
# M3: epochs(25)
# R2 Score :
# Train Dataset: 54.8513 %
# Validation Dataset: 53.9042 %
#
#
# RMSE Score :
# Train Dataset: 3375.1217
# Validation Dataset: 3251.4261
#
# -------------------------------------------------------------------------------------------------------------------------------
#
# # model:4
# def model_m4():
#     model = Sequential()
#
#     model.add(Dense(35, activation='linear', input_dim=74))
#     model.add(Dropout(0.4))
#     model.add(Dense(45, activation='relu'))
#     model.add(Dropout(0.3))
#     model.add(Dense(1, activation='linear'))
#
#     model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate=0.001), loss='mean_squared_error')
#
#     return model
#
# RESULT:
# -----------------------------
#
# M4: epochs(14)
# R2 Score :
# Train Dataset: 62.9923 %
# Validation Dataset: 66.2068 %
#
#
# RMSE Score :
# Train Dataset: 3055.7147
# Validation Dataset: 2783.9263
#
# -------------------------------------------------------------------------------------------------------------------------------
#
# # model:5
# def model_m5():
#     model = Sequential()
#
#     model.add(Dense(50, activation='relu', input_dim=74))
#     model.add(Dropout(0.3))
#     model.add(Dense(30, activation='tanh'))
#     model.add(Dropout(0.2))
#     model.add(Dense(1, activation='linear'))
#
#     model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')
#
#     return model
#
# RESULT:
# -----------------------------
#
# R2 Score :
# Train Dataset: -0.522 %
# Validation Dataset: -0.0021 %
#
#
# RMSE Score :
# Train Dataset: 5036.137
# Validation Dataset: 4789.0307
#
# -------------------------------------------------------------------------------------------------------------------------------
#
# # model:6
# def model_m6():
#     model = Sequential()
#
#     model.add(Dense(74, activation='relu', input_dim=74))
#     model.add(Dropout(0.3))
#     model.add(Dense(32, activation='tanh'))
#     model.add(Dropout(0.2))
#     model.add(Dense(1, activation='linear'))
#
#     model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001), loss='mean_squared_error')
#
#     return model
#
# RESULT:
# -----------------------------
#
# M6: epochs(18)
# R2 Score :
# Train Dataset: -0.4676 %
# Validation Dataset: -0.0075 %
#
#
# RMSE Score :
# Train Dataset: 5034.7731
# Validation Dataset: 4789.1594
#
# -------------------------------------------------------------------------------------------------------------------------------
#
# # model:7
# def model_m7():
#     model = Sequential()
#
#     model.add(Dense(50, activation='relu', input_dim=74))
#     model.add(Dropout(0.4))
#     model.add(Dense(50, activation='tanh'))
#     model.add(Dropout(0.5))
#     model.add(Dense(25, activation='relu'))
#     model.add(Dropout(0.2))
#     model.add(Dense(1, activation='linear'))
#
#     model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')
#
#     return model
#
# RESULT:
# -----------------------------
#
# M7: epochs(20)
# R2 Score :
# Train Dataset: 65.861 %
# Validation Dataset: 68.0333 %
#
#
# RMSE Score :
# Train Dataset: 2934.8925
# Validation Dataset: 2707.6454
#
# -------------------------------------------------------------------------------------------------------------------------------
#
# # model:8
# def model_m8():
#     model = Sequential()
#
#     model.add(Dense(50, activation='relu', input_dim=74))
#     model.add(Dropout(0.1))
#     model.add(Dense(40, activation='linear'))
#     model.add(Dropout(0.1))
#     model.add(Dense(30, activation='relu'))
#     model.add(Dropout(0.1))
#     model.add(Dense(1, activation='linear'))
#
#     model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001), loss='mean_squared_error')
#
#     return model
#
# RESULT:
# -----------------------------
#
# M8: epochs(24)
# R2 Score :
# Train Dataset: 64.1224 %
# Validation Dataset: 68.0833 %
#
#
# RMSE Score :
# Train Dataset: 3008.7002
# Validation Dataset: 2705.5293

# %% [markdown]
# ## D. Best Model (Model with higher R2 score for both Train and Validation Dataset)

# %% [markdown]
# #### 1. Feature Engineering. (One Hot Encoding, Ordinal Encoding)
# #### 2. Hyper Parameters tuning model.
#
# #### 3. Input Dataset Size:
# - X-Train Dataset size : (549868, 74)
# - X-Validation Dataset size : (100, 74)
#
#
# #### 4. Model: ANN Model
#
#     def model_m7():
#         model = Sequential()
#
#         model.add(Dense(50, activation='relu', input_dim=74))
#         model.add(Dropout(0.4))
#         model.add(Dense(50, activation='tanh'))
#         model.add(Dropout(0.5))
#         model.add(Dense(25, activation='relu'))
#         model.add(Dropout(0.2))
#         model.add(Dense(1, activation='linear'))
#
#         model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')
#
#         return model
#
#     best_mdl = model_m7()
#     best_mdl.summary()
#
#     hst = best_mdl.fit(Xtr, ytr, epochs=20, verbose=1, validation_data=(Xval,yval))
#
# #### 5. Results:
# - R2 Score :
#   - Train Dataset: 65.861 %
#   - Validation Dataset: 68.0333 %
#
# - RMSE Score :
#   - Train Dataset: 2934.8925
#   - Validation Dataset: 2707.6454
#
# #### 6. Conclusions:
# - ***Acceptable performance for Train and Validation sets.***
# - ***Model is performing better on validation dataset in comparison to train dataset.***

# %% [markdown]
# #### 7. Performance on Both Datasets (Train and Validation)

# %%
from IPython.display import Image
Image(filename='./assets/img/res_best_prod_model.png')

# %% [markdown]
# ## E. Gradio App Deployment Files
#
# - Production Model saved as 'mdl_final.keras' file.
# - Xtrain set is saved 'bfs_train_pp.pkl' file. To access the feature unique values, and ranges.
# - Test set is saved 'bfs_test_pp.pkl' file. To test the app.
